# %%
import torch

x = torch.randn(1, 3, 224, 224)
print(x)
# Out:
# tensor([[[[-1.1764e-01, -1.4756e+00,  7.0279e-01,  ..., -6.1801e-01,
#             9.1470e-01, -1.1059e-01],
#           [ 6.6811e-01, -2.1147e+00, -1.3293e+00,  ...,  4.5887e-01,
#            -2.9569e+00, -1.0201e+00],
#           [-5.0189e-01, -1.2013e+00, -1.4096e+00,  ..., -4.2580e-01,
#            -4.1975e-01, -3.9899e-01],
#           ...,
#           [ 5.3530e-01,  1.1845e-01, -3.3798e-01,  ...,  9.7282e-01,
#             3.6278e+00, -3.7860e-01],
#           [-3.3583e-01, -1.7479e+00, -1.7179e+00,  ...,  1.2985e+00,
#             1.5167e+00,  3.4690e-03],
#           [ 1.3308e-01,  1.0375e+00, -9.1020e-01,  ..., -2.3145e+00,
#            -9.5117e-01, -6.9470e-01]],
#
#          [[-5.7575e-02, -1.4169e+00,  3.5811e-01,  ..., -1.4696e+00,
#            -9.3450e-01,  9.5707e-01],
#           [-1.7627e+00, -6.9748e-01,  2.2115e+00,  ..., -4.8104e-01,
#             2.3470e-01, -9.0916e-01],
#           [ 7.9405e-01, -2.5817e-01,  1.0767e+00,  ...,  8.2328e-01,
# ...
